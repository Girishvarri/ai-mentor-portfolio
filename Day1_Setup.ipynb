# %% [markdown]
# <a href="https://colab.research.google.com/github/Girishvarri/ai-mentor-portfolio/blob/main/Day1_Setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q google-genai

# %%
import os, getpass
os.environ['GEMINI_API_KEY'] = getpass.getpass('Paste your Google AI Studio key: ')
# Out:
# Paste your Google AI Studio key: ··········

# %%
from google import genai
client = genai.Client(api_key=os.environ['GEMINI_API_KEY'])

resp = client.models.generate_content(
    model='gemini-2.5-flash',
    contents='Explain the 5-Layer AI Skill Pyramid in 4 short bullet points.'
)
print(resp.text)
# Out:
# The 5-Layer AI Skill Pyramid outlines the progressive skills needed to build, deploy, and leverage AI, from foundational technical work to strategic innovation:
#
# *   **Layer 1: Data Management & Engineering:** The base focuses on acquiring, cleaning, storing, and labeling data, which is fundamental for any AI system.
# *   **Layer 2: Model Development & Training:** This layer involves selecting algorithms, feature engineering, training, and evaluating AI models.
# *   **Layer 3: Deployment & MLOps:** Focuses on operationalizing AI, including integrating models into systems, scaling, monitoring performance, and maintaining models in production.
# *   **Layer 4: Business Acumen & Strategy:** Emphasizes understanding business problems, defining AI use cases, assessing ROI, and navigating ethical considerations to ensure AI delivers value.
# *   **Layer 5: AI Research & Innovation:** The apex involves pushing the boundaries of AI, developing new algorithms, and contributing to fundamental advancements in the field.
