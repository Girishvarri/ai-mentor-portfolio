# %% [markdown]
# **claude Promte -1**

# %% [markdown]
# https://chatgpt.com/share/6a0ea375-0c88-8322-92b4-1e930d44e641

# %% [markdown]
# https://claude.ai/chat/8bf6f301-0b9e-4e3c-8dba-bdf92f075ada

# %% [markdown]
# **claude Promte -2**

# %% [markdown]
# https://chatgpt.com/share/6a0ea4bd-1a50-8320-808e-cc9c4b482281

# %% [markdown]
# https://claude.ai/share/1ee88a04-a200-45b7-8a16-a4f8b31484b0

# %% [markdown]
# **claude Promte -3**

# %% [markdown]
# https://chatgpt.com/share/6a0ea569-609c-8324-a5ed-ed4d269c7d35

# %% [markdown]
# https://claude.ai/share/6100e33b-fdf0-405c-870f-26f9369d3884

# %% [markdown]
# **claude Promte -4**

# %% [markdown]
# https://chatgpt.com/share/6a0ea5ef-47cc-8323-8613-6b6e180c31a6

# %% [markdown]
# https://claude.ai/share/6dc9a76e-f2d2-4c9f-966d-0474aeeba2fc

# %% [markdown]
# **claude Promte -5**

# %% [markdown]
# https://chatgpt.com/share/6a0ea63f-5a00-8320-be6f-4d41bb6cc655

# %% [markdown]
# https://claude.ai/share/fdcb04be-a089-4e83-8960-8fd51afbb002

# %% [markdown]
# **claude Promte -6**

# %% [markdown]
# https://chatgpt.com/share/6a0ea6f5-86fc-8321-a28b-200656edc4bd

# %% [markdown]
# https://claude.ai/share/56b05233-c240-4599-ad45-a00fc0eeeac7
